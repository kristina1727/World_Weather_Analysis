# %%
# Dependencies and Setup
import requests
import gmaps
from pprint import pprint

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url,params = params).json()

pprint(hotels)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEClPjcYMc5bB9PObBE43Jf7xm74c1IjRmPOjntQ-edJGZXAZDajbNmZoPtsirhbQpWlO-mF0lhmvpUaWN890Q7-ecTIU87kkvSqpVaKBp9XE6q3XriVSSdna72acf8mUSOqfOPSP589WUYs493Yf2YbwXy5IbStakALEM0Tg7dvI3rSAZLfg4AV6-rE6hz6EVLiQ4llYIuBWaMGEQUj-YZ5zvljb3N0Zrf84c3mnkfV2-H8dV8QyOg3rgpcSz6f9Dk9M6BGFok61-5B6qcNovZPVcKaa-8zW715EyDr3YmF0PpZNLz_NPzWDjt7I9M6aNRykENmeoEcoR6AliZVPTQ6nYJ0EIxSjJM9UJ-t0Finbh2EfEx_KwVESWaeBlEN8niIFba6DtDvZOkBPmpScYQJrFRI2eSIlv4jzZYFaTPyi8jReMRInY24',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#                            'viewport': {'northeast': {'lat': 48.8594360302915,
#                                                       'lng': 2.354355480291502},
#                                         'southwest': {'lat': 48.8567380697085,
#                                                       'lng': 2.351657519708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Duo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3840,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel '
#                                                 'Duo</a>'],
#                           'photo_reference': 'Aap_uECdOZ-fSB_RpeOX8Iq4bAmT6dqk3foN5aHfe40zSvJBI0NVvJUncij8NReLdZFjHm_ukzqG9gQv4dzD6msqRpeFq76higsGyGKZJuJ65GyfgdRTc0aXQVr_OKCkIDFJGIjgHIg8NHb1sqOyZSf80Z6YWNd1cznhrg_FSdu3BIsjODE_',
#                           'width': 5760}],
#               'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#               'plus_code': {'compound_code': 'V953+65 Paris, France',
#                             'global_code': '8FW4V953+65'},
#               'rating': 4.2,
#               'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#               'scope': 'GOOGLE',
#               'types': ['night_club',
#                         'spa',
#                         'lodging',
#                         'bar',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 302,
#               'vicinity': '11 Rue du Temple, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#                            'viewport': {'northeast': {'lat': 48.85954748029151,
#                                                       'lng': 2.347782830291502},
#                                         'southwest': {'lat': 48.85684951970851,
#                                                       'lng': 2.345084869708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Britannique - Paris Centre',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1426,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel '
#                                                 'Britannique - Paris '
#                                                 'Centre</a>'],
#                           'photo_reference': 'Aap_uEASN_E0KXGfU578VluTAJDL5MuGQ6emFJPkzLzFxr-i2Lub1nmQQPUXWmZvxi6ttRx89IngsLxhIm_B8LOcVS9koZqqAaC5Mnbsb059og4U9chYJ0ql1vJ3yLo0kTC0gigbTg3CXngkGyKJdDFr3BgiX34IeICb1jJzQ2r5CXzLR2sh',
#                           'width': 1476}],
#               'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#               'plus_code': {'compound_code': 'V85W+8H Paris, France',
#                             'global_code': '8FW4V85W+8H'},
#               'rating': 4.6,
#               'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 626,
#               'vicinity': '20 Avenue Victoria, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#                            'viewport': {'northeast': {'lat': 48.8617653302915,
#                                                       'lng': 2.348020880291502},
#                                         'southwest': {'lat': 48.85906736970851,
#                                                       'lng': 2.345322919708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Citadines Les Halles Paris',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 849,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines '
#                                                 'Les Halles Paris (Apart hotel '
#                                                 'Paris)</a>'],
#                           'photo_reference': 'Aap_uEBExM7sjbpaL57sXV_SRitBEh2o8pqtMCYlAJL3SObh2UocDtDzlwGXM-SbywoYJ2hY3X4HqBvlQrqa9gZm1ujLOGPqBVfSxpRMxTTioHipYK2OzcltZ7uYIT0qD_oKLw2vlwhk65mAomR2SrDinY71-0b8x2etYzEDsNcIgO5Tcn18',
#                           'width': 1280}],
#               'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#               'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#                             'global_code': '8FW4V86W+7Q'},
#               'rating': 4.1,
#               'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 861,
#               'vicinity': '4 Rue des Innocents, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#                            'viewport': {'northeast': {'lat': 48.8620584302915,
#                                                       'lng': 2.347692880291501},
#                                         'southwest': {'lat': 48.85936046970851,
#                                                       'lng': 2.344994919708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Novotel Paris Les Halles',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel '
#                                                 'Paris Les Halles</a>'],
#                           'photo_reference': 'Aap_uEDkHhl_BOgJfhmTCZtv-c5oS9vqrxwJQb_06UqP2HevnTeytZttna-Imp-Jw9xcl_DV5M0Jrq0oQmihCmbpX4Jicgi2Q_OXze4OXfOgQvVqmSHfn1dMgsf_zBKDzrj-EB-ucPAfaI-ZeQE05Qc12Iu5pUa476YLqgTYVODBkhaQ0ZS6',
#                           'width': 3000}],
#               'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#               'plus_code': {'compound_code': 'V86W+8J Paris, France',
#                             'global_code': '8FW4V86W+8J'},
#               'rating': 4.4,
#               'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2245,
#               'vicinity': '8 Place Marguerite de Navarre, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#                            'viewport': {'northeast': {'lat': 48.86165553029149,
#                                                       'lng': 2.345549080291502},
#                                         'southwest': {'lat': 48.8589575697085,
#                                                       'lng': 2.342851119708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Ducs de Bourgogne',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1390,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel '
#                                                 'Ducs de Bourgogne</a>'],
#                           'photo_reference': 'Aap_uECJIYYgrfZPLSNpgtOiLMjzkNcbMGg4aNGVkbV80oD9D68MAmmiSD2mIs_Zmn-LUvPrJ2FH1-N-hxC7o6CZVNe7iN_pqFVR03ZNGPX9Eb3M42XGkX98IEZ-IFV9dtFx6j7OP_VP9nXFKbnexXIz4lLfXzgpoIxXhoVZ0wJs88E5sKx9',
#                           'width': 2048}],
#               'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#               'plus_code': {'compound_code': 'V86V+4J Paris, France',
#                             'global_code': '8FW4V86V+4J'},
#               'rating': 4.5,
#               'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 279,
#               'vicinity': '19 Rue du Pont Neuf, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#                            'viewport': {'northeast': {'lat': 48.8569076302915,
#                                                       'lng': 2.342319280291502},
#                                         'southwest': {'lat': 48.8542096697085,
#                                                       'lng': 2.339621319708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel '
#                       'Paris)',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4480,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines '
#                                                 'Saint-Germain-des-Prés '
#                                                 'Paris</a>'],
#                           'photo_reference': 'Aap_uEBhFBuB9nLGabhUkAIFe6eFB2afIzW9CbFeDW_FcVRN0oWgDcTw8ma5Tn3LiLWZ-EdJT2kWP-OsN04MjxDv4ib52ixWRhcbjk6EMANJeMt6gDm43p71WoiPdxVJYzK7eqRG2g1UVtiehDTWF3mpahZMbQzWhjBg0mofLmJC8jjMDod7',
#                           'width': 6720}],
#               'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#               'plus_code': {'compound_code': 'V84R+68 Paris, France',
#                             'global_code': '8FW4V84R+68'},
#               'rating': 4.3,
#               'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 707,
#               'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8663519, 'lng': 2.3606461},
#                            'viewport': {'northeast': {'lat': 48.86775308029149,
#                                                       'lng': 2.361905130291502},
#                                         'southwest': {'lat': 48.8650551197085,
#                                                       'lng': 2.359207169708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Paris France Hôtel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2673,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102332962500946068613">Paris '
#                                                 'France Hôtel</a>'],
#                           'photo_reference': 'Aap_uEBl4gThlIg0bYs93mV7aNaoDaYrewX5N2qInzmr6JLLa5Nq-D1-NEwsmcmVIePPDmO4hSwZ1hBuUWKwBDX-LMXDsprqV7EPG74Xbh7w3mfMd7s4fgjaAQF7Nkgss51kzATlL7swSkb2mw-cGlno437WlB5wZKJFKkvmh_ebUY3N0HEL',
#                           'width': 3463}],
#               'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#               'plus_code': {'compound_code': 'V986+G7 Paris, France',
#                             'global_code': '8FW4V986+G7'},
#               'rating': 4.3,
#               'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 387,
#               'vicinity': '72 Rue de Turbigo, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.86386539999999,
#                                         'lng': 2.3325488},
#                            'viewport': {'northeast': {'lat': 48.8650759802915,
#                                                       'lng': 2.333775730291502},
#                                         'southwest': {'lat': 48.8623780197085,
#                                                       'lng': 2.331077769708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Regina Louvre',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3700,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel '
#                                                 'Regina Louvre</a>'],
#                           'photo_reference': 'Aap_uECNTQEVzSqlS8z5yXFKkAk2xrPCNWySkO1Odc6LQzgTrh6ZMgshlVAb9d87HJQL4fA9InyCIriSTv3VF1itPDPBWwkYFi5QlWg45C9VSMyCM3bzDnS3sxbwH-2CuuLZxuTTmqKLtAgmahc2TDBziN2ZRiyoWxpiLTyxTETAjLkKuMkV',
#                           'width': 5550}],
#               'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#               'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#                             'global_code': '8FW4V87M+G2'},
#               'rating': 4.4,
#               'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 507,
#               'vicinity': '2 Place des Pyramides, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.84795229999999,
#                                         'lng': 2.370869},
#                            'viewport': {'northeast': {'lat': 48.8492035302915,
#                                                       'lng': 2.372290080291501},
#                                         'southwest': {'lat': 48.8465055697085,
#                                                       'lng': 2.369592119708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2048,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin '
#                                                 'Nguyen</a>'],
#                           'photo_reference': 'Aap_uECUUMtEzxeVFVm_YGLJHqzxv68znPHZtFMxWD0nM-mDNOOIVC3S6kuF4kfINz9BiFol_kKJraiJG44a2lGbj281MVDtenUcIb59-tKe4AAyYZcBGwU-PBymH5IWboceHXS-XAL0z2sFkqinDvs8O6T2ChQfPI2embvIUHUNcSmMeC9R',
#                           'width': 1536}],
#               'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#               'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#                             'global_code': '8FW4R9XC+58'},
#               'rating': 4.1,
#               'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 836,
#               'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#                            'viewport': {'northeast': {'lat': 48.87241888029151,
#                                                       'lng': 2.351188530291502},
#                                         'southwest': {'lat': 48.86972091970851,
#                                                       'lng': 2.348490569708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel des Comédies Paris',
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#                           'photo_reference': 'Aap_uEAYyYOslm_CxtvYG_iKRqK1bMzYUxbK5gI-vVClVvaIYq2XX1hZuWkeKMBlPGj6dCB85TLwEwSXZLGXEt6ReduVzsgzEfhXDlM6ePudVCNqV4r4E0aIGH_0ZUbO2g4yIiW7kAaoImTNsK5gpEYCN28dU8bFCde1DwF3l8dWOWuXV-uS',
#                           'width': 3000}],
#               'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#               'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#                             'global_code': '8FW4V8CX+CX'},
#               'rating': 4.2,
#               'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 195,
#               'vicinity': "8 Rue d'Hauteville, Paris"},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.84754640000001,
#                                         'lng': 2.3718722},
#                            'viewport': {'northeast': {'lat': 48.8488750302915,
#                                                       'lng': 2.373125480291502},
#                                         'southwest': {'lat': 48.8461770697085,
#                                                       'lng': 2.370427519708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel De France Gare de Lyon Bastille',
#               'photos': [{'height': 787,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel '
#                                                 'De France Gare de Lyon '
#                                                 'Bastille</a>'],
#                           'photo_reference': 'Aap_uEC7ztf4srBt9XS56gEfHyLax7gMmJHLC-eQfzl25KpNXjlwAh47jGxhj6_3fSudKbGWq7eaAlLq15bWFxqSCh1EXuzcuiyfzGV0Q1He2CwTPKXvT1hXEF29oPpZhIUYdFbdO3CuNRtO_n7EOFVblMeRdx7c81w5VNt-WsGTM3rIAlF4',
#                           'width': 1181}],
#               'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#               'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#                             'global_code': '8FW4R9XC+2P'},
#               'rating': 3.3,
#               'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 381,
#               'vicinity': '12 Rue de Lyon, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#                            'viewport': {'northeast': {'lat': 48.8731374802915,
#                                                       'lng': 2.346059980291502},
#                                         'southwest': {'lat': 48.8704395197085,
#                                                       'lng': 2.343362019708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Prélude Opéra Paris',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 5120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113098608949799179620">Chrystelle '
#                                                 'Baudry</a>'],
#                           'photo_reference': 'Aap_uEC4vRrF0cNKsalFR650z-8Vr0MVSw6dudjFPsBwClMyFky8Dsb1RGLPjyq5QtHyZthYLvFQ6YvCXyevvFyNBqWlNP6v0UWvye_wPNLMmg8kQHkuENP4m1qySAxvgq8g6rYQCPTH2RH8VB_y8pdPzTVObdbLYFXBJ_vZGjnfbTLhVHdT',
#                           'width': 3840}],
#               'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#               'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#                             'global_code': '8FW4V8CV+MV'},
#               'rating': 4.2,
#               'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 375,
#               'vicinity': '8 Cité Bergère, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#                            'viewport': {'northeast': {'lat': 48.8436624802915,
#                                                       'lng': 2.364708880291502},
#                                         'southwest': {'lat': 48.8409645197085,
#                                                       'lng': 2.362010919708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4480,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel '
#                                                 'Libertel Austerlitz Jardin '
#                                                 'des Plantes</a>'],
#                           'photo_reference': 'Aap_uEC7v58qygWkRz6I41bslp8EzK0UTx_EV2qZWUR-ndeUx5Go7YSijhsQ15npqJD81tWvc6WFVRU2SX-sOE2WSkTesTdJJLgbt3Kil2hvFcdWiu_r1xuDhB2pdv3lqcvs1q6MU5ekt48MOsMDW_jLjJxc4gzBW1y_z8MakdbQ6rESvoBG',
#                           'width': 6720}],
#               'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#               'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#                             'global_code': '8FW4R9R7+W7'},
#               'rating': 4,
#               'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 440,
#               'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8642974, 'lng': 2.3308142},
#                            'viewport': {'northeast': {'lat': 48.8655789302915,
#                                                       'lng': 2.332153980291502},
#                                         'southwest': {'lat': 48.8628809697085,
#                                                       'lng': 2.329456019708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Saint James Albany Paris Hôtel Spa',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 400,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108570400659068256718">Saint '
#                                                 'James Albany Paris Hôtel '
#                                                 'Spa</a>'],
#                           'photo_reference': 'Aap_uEBhwvwq_DxpNWLL-8JbaiScwNFuWzJZot5HVllkeUfJOVjIOYAPFSWxJQ5a7IDGqhB8x0byZxAOzxmDo6BEgYRwNiEtMvmke9Swh0jCL9AAk_I2piDtazf4ef0l6JFv47Lq6v09ym5Mui67zn00uJH5ofe1cq1t7Gf4McHs3kdQjBJX',
#                           'width': 600}],
#               'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#               'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#                             'global_code': '8FW4V87J+P8'},
#               'rating': 4,
#               'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1075,
#               'vicinity': '202 Rue de Rivoli, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.87110329999999,
#                                         'lng': 2.3389728},
#                            'viewport': {'northeast': {'lat': 48.8724588802915,
#                                                       'lng': 2.340112930291502},
#                                         'southwest': {'lat': 48.8697609197085,
#                                                       'lng': 2.337414969708499}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Icône',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1066,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel '
#                                                 'Icône</a>'],
#                           'photo_reference': 'Aap_uEAChD6yJ3ilykQ5sn2oOUPeeA79Y4M8F-OC2G_QvFB9Qn9l1AgHZnRxfEJlcHOX0CgqzOI7T43nRLTEh8uJHQ1AAkpjm_ojOrBGSegMP0flBbaLlHxFLXQ2M6kglfVydnhrYI04aPwf5Z0Rl5BhFE-d5twkc9RxvhPCrOETdmmgX-S9',
#                           'width': 1600}],
#               'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#               'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#                             'global_code': '8FW4V8CQ+CH'},
#               'rating': 3.7,
#               'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 141,
#               'vicinity': "4 Rue d'Amboise, Paris"},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#                            'viewport': {'northeast': {'lat': 48.8538838802915,
#                                                       'lng': 2.348601530291502},
#                                         'southwest': {'lat': 48.8511859197085,
#                                                       'lng': 2.345903569708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel Esmeralda',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia '
#                                                 'Hentze</a>'],
#                           'photo_reference': 'Aap_uEDz5BY0xDN4Fj62rswp_F5zXFhz84j1JjojDKGcJ4VwIV8p8uYCgHlsSC8PDFSdR4hvjevivlWg2--MzQz_Ye7KaZEFDpzH55JKo2Rnb5dK_crMQz-4sQmezjNWFOE32oPcW6OuYHVMg-of8CNkPkRrouQslYjusapfjx65xXdXj-ar',
#                           'width': 3024}],
#               'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#               'plus_code': {'compound_code': 'V82W+XV Paris, France',
#                             'global_code': '8FW4V82W+XV'},
#               'rating': 4.1,
#               'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 146,
#               'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#                            'viewport': {'northeast': {'lat': 48.8544403302915,
#                                                       'lng': 2.346001280291502},
#                                         'southwest': {'lat': 48.8517423697085,
#                                                       'lng': 2.343303319708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Albe Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117571951379278191466">Albe '
#                                                 'Hotel Saint Michel</a>'],
#                           'photo_reference': 'Aap_uECL81Ss9PqwJi4D9Dp5lzDmBHurD7NHTFUNGclBD-r9_EpzyfmfPtzz0qSkAVQ3-zG2ZSA6t3cF0LJy8DHqXd09OImTRbVYwBoAxdIhJgC0fx2zbXa8P_7kL-S2db6us3aI2dzheVJfJ5jlWz21weX0PRzsPjWDXeUsj38SLRtbhbQn',
#                           'width': 1600}],
#               'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#               'plus_code': {'compound_code': 'V83V+6V Paris, France',
#                             'global_code': '8FW4V83V+6V'},
#               'rating': 4.4,
#               'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 331,
#               'vicinity': '1 Rue de la Harpe, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#                            'viewport': {'northeast': {'lat': 48.8512737302915,
#                                                       'lng': 2.347507380291502},
#                                         'southwest': {'lat': 48.8485757697085,
#                                                       'lng': 2.344809419708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Home Latin',
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108547915404801536469">Jp '
#                                                 'Homma</a>'],
#                           'photo_reference': 'Aap_uECaP2yHUsMBR-KIH2DkuNl96GYb8MxA361xnA3OGmenh8vsBi7JMCygSAzewynCsJ-FuCTNZJOMae0UsAldRmDT7h5WnovmTryWwRIRrJyyhVUMCQQNNnCmHh86LNU21YaI-fz0j569jRvqc8HwkbnwR_MHIl1b74-OKm3ak6k6kTXM',
#                           'width': 4608}],
#               'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#               'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#                             'global_code': '8FW4R8XW+XF'},
#               'rating': 3.5,
#               'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 286,
#               'vicinity': '15-17 Rue du Sommerard, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.85473870000001,
#                                         'lng': 2.3395455},
#                            'viewport': {'northeast': {'lat': 48.8561127802915,
#                                                       'lng': 2.340820530291502},
#                                         'southwest': {'lat': 48.8534148197085,
#                                                       'lng': 2.338122569708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': "Hôtel d'Aubusson",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2174,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel '
#                                                 'd&#39;Aubusson Paris</a>'],
#                           'photo_reference': 'Aap_uECjtwGuJ4l6iEUNOpGAskm_vbbavaP5TiogolLIFEm6rBfR2dM7k2jzdULyV4iOiRoA5YbsDRWqfCErAHrNN6aY582AM9IPdBXFgWsd7J4bpywnI70EvP48MbBeNMEu5yK05FNrCI9XLFN2x6hw9xI_DI0q_8vjx12fE-nWQcRmCeEG',
#                           'width': 1739}],
#               'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#               'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#                             'global_code': '8FW4V83Q+VR'},
#               'rating': 4.7,
#               'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 293,
#               'vicinity': '33 Rue Dauphine, Paris'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.85184049999999,
#                                         'lng': 2.3448082},
#                            'viewport': {'northeast': {'lat': 48.8531470802915,
#                                                       'lng': 2.346121880291502},
#                                         'southwest': {'lat': 48.8504491197085,
#                                                       'lng': 2.343423919708498}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit '
#                       'de France',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2362,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel '
#                                                 '4 étoiles Parc Saint Séverin '
#                                                 'Paris 5ème - Esprit de '
#                                                 'France</a>'],
#                           'photo_reference': 'Aap_uECwpgGJuI5wzZNt4DTzfxR4e2YMjJ0E9mqpen_S2FtQNxGbdWxtfqj4zaen5Z94749Msy_9VgjXPrQS9hE8ShYNRqv3Ljeb0VdXWfYZRohYZ2gwrTSRyZUC-YLM5JESYHK5xLsAQ1aAW7q0VkiGEcHNjZjM305K-aCtcLpBjarAN2XU',
#                           'width': 3776}],
#               'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#               'plus_code': {'compound_code': 'V82V+PW Paris, France',
#                             'global_code': '8FW4V82V+PW'},
#               'rating': 4.6,
#               'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 140,
#               'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
len(hotels['results'])
# Out:
# 20

# %%
hotels['results'][0]['name']
# Out:
# 'Hôtel Duo'
